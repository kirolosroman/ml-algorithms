# %%
import pandas as pd

# %% [markdown]
# ## two main datatypes in pandas
# ### 1- series is 1-dimensional

# %%
series=pd.Series(['honda','toyota','bmw','mercedez'])
series
# Out:
# 0       honda
# 1      toyota
# 2         bmw
# 3    mercedez
# dtype: object

# %%
colours=pd.Series(['red','blue','green','yellow'])
colours
# Out:
# 0       red
# 1      blue
# 2     green
# 3    yellow
# dtype: object

# %% [markdown]
# ### 2-dataframe is 2-dimensional

# %%
cars_data=pd.DataFrame({"cars":series,"colour":colours})
cars_data
# Out:
#        cars  colour
# 0     honda     red
# 1    toyota    blue
# 2       bmw   green
# 3  mercedez  yellow

# %% [markdown]
# ## importing data

# %%
car_sales=pd.read_csv("C:/krh/dev/python/ml/datsets/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## exporting data to a csv file

# %%
car_sales.to_csv("C:/krh/dev/python/ml/datsets/car-sales_test.csv",index=False)

# %% [markdown]
# ## Describe the data

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()# works only on numeric columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %% [markdown]
# ## .loc and .iloc

# %%
animals=pd.Series(['cat','dog','frog','wolf','lion'],index=[0,3,6,4,3])
animals
# Out:
# 0     cat
# 3     dog
# 6    frog
# 4    wolf
# 3    lion
# dtype: object

# %%
animals.loc[3]
# Out:
# 3     dog
# 3    lion
# dtype: object

# %%
animals.loc[6]
# Out:
# 'frog'

# %%
animals.iloc[3]
# Out:
# 'wolf'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 6    frog
# dtype: object

# %%
car_sales.iloc[:]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %% [markdown]
# ## comparing two columns

# %%
pd.crosstab(car_sales['Make'],car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# ## groupby

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# ## plotting data in a simple graph

# %%
car_sales['Odometer (KM)'].plot()
# Out:
# <Axes: >

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <Axes: >

# %%
#car_sales['Price']=car_sales['Price'].str.replace('[\$\,\.]', '').astype(float)
car_sales['Price'].dtype
car_sales['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_sales['Price'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales['Make']=car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
missing_car_sales=pd.read_csv("C:/krh/dev/python/ml/datsets/car-sales-missing-data.csv")

# %%
missing_car_sales
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ## filing missing data

# %%
missing_car_sales['Odometer']=missing_car_sales['Odometer'].fillna(missing_car_sales['Odometer'].mean())

# %%
missing_car_sales
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
missing_car_sales.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# ## column from series

# %%
seats_column=pd.Series([5,5,5,5,5])

car_sales['Seats']=seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    NaN
# 6   honda   Blue          45698      4   $7,500.00    NaN
# 7   honda   Blue          54738      4   $7,000.00    NaN
# 8  toyota  White          60000      4   $6,250.00    NaN
# 9  nissan  White          31600      4   $9,700.00    NaN

# %%
car_sales['Seats'].fillna(5,inplace=True)
# Out:
# C:\Users\kirol\AppData\Local\Temp\ipykernel_14640\4074521166.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales['Seats'].fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats
# 0  toyota  White         150043      4   $4,000.00    5.0
# 1   honda    Red          87899      4   $5,000.00    5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0
# 3     bmw  Black          11179      5  $22,000.00    5.0
# 4  nissan  White         213095      4   $3,500.00    5.0
# 5  toyota  Green          99213      4   $4,500.00    5.0
# 6   honda   Blue          45698      4   $7,500.00    5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0
# 8  toyota  White          60000      4   $6,250.00    5.0
# 9  nissan  White          31600      4   $9,700.00    5.0

# %%
fuel_economy=[6,3.5,4.3,6.8,7,3,5,6,8,9]#it has to be the same length as the data frame
car_sales['fuel per 100km']=fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 1   honda    Red          87899      4   $5,000.00    5.0             3.5
# 2  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 3     bmw  Black          11179      5  $22,000.00    5.0             6.8
# 4  nissan  White         213095      4   $3,500.00    5.0             7.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 8  toyota  White          60000      4   $6,250.00    5.0             8.0
# 9  nissan  White          31600      4   $9,700.00    5.0             9.0

# %%
car_sales['total fuel used']=car_sales['Odometer (KM)']/100*car_sales['fuel per 100km']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 1   honda    Red          87899      4   $5,000.00    5.0             3.5
# 2  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 3     bmw  Black          11179      5  $22,000.00    5.0             6.8
# 4  nissan  White         213095      4   $3,500.00    5.0             7.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 8  toyota  White          60000      4   $6,250.00    5.0             8.0
# 9  nissan  White          31600      4   $9,700.00    5.0             9.0
#
#    total fuel used
# 0         9002.580
# 1         3076.465
# 2         1399.607
# 3          760.172
# 4        14916.650
# 5         2976.390
# ...

# %%
# create a column from a single value
car_sales['wheels']=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 1   honda    Red          87899      4   $5,000.00    5.0             3.5
# 2  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 3     bmw  Black          11179      5  $22,000.00    5.0             6.8
# 4  nissan  White         213095      4   $3,500.00    5.0             7.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 8  toyota  White          60000      4   $6,250.00    5.0             8.0
# 9  nissan  White          31600      4   $9,700.00    5.0             9.0
#
#    total fuel used  wheels
# 0         9002.580       4
# 1         3076.465       4
# 2         1399.607       4
# 3          760.172       4
# ...

# %%
car_sales['passed through saftey']=True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 1   honda    Red          87899      4   $5,000.00    5.0             3.5
# 2  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 3     bmw  Black          11179      5  $22,000.00    5.0             6.8
# 4  nissan  White         213095      4   $3,500.00    5.0             7.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 8  toyota  White          60000      4   $6,250.00    5.0             8.0
# 9  nissan  White          31600      4   $9,700.00    5.0             9.0
#
#    total fuel used  wheels  passed through saftey
# 0         9002.580       4                   True
# 1         3076.465       4                   True
# ...

# %%
car_sales.drop('passed through saftey',axis=1,inplace=True)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 1   honda    Red          87899      4   $5,000.00    5.0             3.5
# 2  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 3     bmw  Black          11179      5  $22,000.00    5.0             6.8
# 4  nissan  White         213095      4   $3,500.00    5.0             7.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 7   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 8  toyota  White          60000      4   $6,250.00    5.0             8.0
# 9  nissan  White          31600      4   $9,700.00    5.0             9.0
#
#    total fuel used  wheels
# 0         9002.580       4
# 1         3076.465       4
# 2         1399.607       4
# 3          760.172       4
# ...

# %%
# shuffle the data
car_sales_shuffle=car_sales.sample(frac=1)
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 9  nissan  White          31600      4   $9,700.00    5.0             9.0
# 4  nissan  White         213095      4   $3,500.00    5.0             7.0
# 1   honda    Red          87899      4   $5,000.00    5.0             3.5
# 8  toyota  White          60000      4   $6,250.00    5.0             8.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 2  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 7   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 3     bmw  Black          11179      5  $22,000.00    5.0             6.8
#
#    total fuel used  wheels
# 0         9002.580       4
# 9         2844.000       4
# 4        14916.650       4
# 1         3076.465       4
# ...

# %%
car_sales_shuffle.reset_index(drop=True,inplace=True)
car_sales_shuffle
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White         150043      4   $4,000.00    5.0             6.0
# 1  nissan  White          31600      4   $9,700.00    5.0             9.0
# 2  nissan  White         213095      4   $3,500.00    5.0             7.0
# 3   honda    Red          87899      4   $5,000.00    5.0             3.5
# 4  toyota  White          60000      4   $6,250.00    5.0             8.0
# 5  toyota  Green          99213      4   $4,500.00    5.0             3.0
# 6   honda   Blue          45698      4   $7,500.00    5.0             5.0
# 7  toyota   Blue          32549      3   $7,000.00    5.0             4.3
# 8   honda   Blue          54738      4   $7,000.00    5.0             6.0
# 9     bmw  Black          11179      5  $22,000.00    5.0             6.8
#
#    total fuel used  wheels
# 0         9002.580       4
# 1         2844.000       4
# 2        14916.650       4
# 3         3076.465       4
# ...

# %%
car_sales['Odometer (KM)']=car_sales['Odometer (KM)'].apply(lambda x:x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  Seats  fuel per 100km  \
# 0  toyota  White      93776.875      4   $4,000.00    5.0             6.0
# 1   honda    Red      54936.875      4   $5,000.00    5.0             3.5
# 2  toyota   Blue      20343.125      3   $7,000.00    5.0             4.3
# 3     bmw  Black       6986.875      5  $22,000.00    5.0             6.8
# 4  nissan  White     133184.375      4   $3,500.00    5.0             7.0
# 5  toyota  Green      62008.125      4   $4,500.00    5.0             3.0
# 6   honda   Blue      28561.250      4   $7,500.00    5.0             5.0
# 7   honda   Blue      34211.250      4   $7,000.00    5.0             6.0
# 8  toyota  White      37500.000      4   $6,250.00    5.0             8.0
# 9  nissan  White      19750.000      4   $9,700.00    5.0             9.0
#
#    total fuel used  wheels
# 0         9002.580       4
# 1         3076.465       4
# 2         1399.607       4
# 3          760.172       4
# ...
